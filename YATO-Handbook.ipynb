# %% [markdown]
# # YATO Handbook
#
# **YATO**, an open-source Python library for text analysis. In particular, **YATO** focus on sequence labeling and sequence classification tasks, including extensive fundamental NLP tasks such as par-of-speech tagging, chunking, NER, CCG supertagging, sentiment analysis, and sentence classification. **YATO** support both designing specific RNN-based and Transformer-based through user-friendly configuration and integrating the SOTA pre-trained language models such as BERT.
#
#
# ## Data Preparation
# **YATO** supports sequence labeling and sequence classification tasks.
# **YATO** offers an official function to convert sequence labeling dataset style.**Location:ncrf.utils.tagSchemeConverter**
# NER Dataset Style: BIO, BIOES, BMES...
# Sequence Classification: Text ||| Label
#
# ## Configuration Preparation
# You can specify the model, optimizer, and decoding through the configuration file.
# ### Dataloader
# train_dir=the path of train file
# dev_dir=the path of validation file
# test_dir=the path of test file
# model_dir=the path to save model weights
# dset_dir=the path of configuration encode file
# ### Model
# use_crf=True/False
# use_char=True/False
# char_seq_feature=GRU/LSTM/CNN/False
# use_word_seq=True/False
# use_word_emb=True/False
# word_emb_dir=The path of word embedding file
# word_seq_feature=GRU/LSTM/CNN/FeedFowrd/False
# low_level_transformer=pretrain language model from huggingface
# low_level_transformer_finetune=True/False
# high_level_transformer=pretrain language model from huggingface
# high_level_transformer_finetune=True/False
# cnn_layer=layer number
# char_hidden_dim=dimension number
# hidden_dim=dimension number
# lstm_layer=layer number
# bilstm=True/False

# %% [markdown]
# #### Architecture

# %% [markdown]
# ![avatar](data:image/png;base64,...)

# %% [markdown]
# #### Low Level Transformer

# %% [markdown]
# ![avatar](data:image/png;base64,...)

# %% [markdown]
# ### Hyperparameters
# sentence_classification=True/False
# status=train/decode
# dropout=Dropout Rate
# optimizer=SGD/Adagrad/adadelta/rmsprop/adam/adamw
# iteration=epoch number
# batch_size=batch size
# learning_rate=learning rate
# gpu=True/False
# device=cuda:0
# scheduler=get_linear_schedule_with_warmup/get_cosine_schedule_with_warmup
# warmup_step_rate=warmup steo rate

# %% [markdown]
# ## Train

# %%
from yato import YATO
model = YATO('demo.bert.config')#configuration file
model.train()
# Out:
# MODEL: train
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Start   Sequence   Laebling   task...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Train  file directory: /home/zqwang/YATO-Github/sample_data/ner.train.bmes
#      Dev    file directory: /home/zqwang/YATO-Github/sample_data/ner.dev.bmes
#      Test   file directory: /home/zqwang/YATO-Github/sample_data/ner.test.bmes
#      Raw    file directory: None
#      Dset   file directory: bert_base_cased.dset
#      Model  file directory: /home/zqwang/YATO-Github/sample_data/
#      Loadmodel   directory: None
#      Decode file directory: None
# ++++++++++++++++++++++++++++++++++++++++
# Data and Settings:
#      Tag          scheme: BIOES
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 512
#      MAX   WORD   LENGTH: -1
#      Number   normalized: False
#      Word         cutoff: 0
#      Train instance number: 484
#      Dev   instance number: 112
#      Test  instance number: 186
#      Raw   instance number: 0
#      Word  alphabet size: 3429
#      Char  alphabet size: 80
#      Label alphabet size: 18
#      Label alphabet content: {'instance2index': {'S-ORG': 1, 'O': 2, 'S-MISC': 3, 'B-PER': 4, 'E-PER': 5, 'S-LOC': 6, 'B-ORG': 7, 'E-ORG': 8, 'I-PER': 9, 'S-PER': 10, 'B-MISC': 11, 'I-MISC': 12, 'E-MISC': 13, 'I-ORG': 14, 'B-LOC': 15, 'E-LOC': 16, 'I-LOC': 17}, 'instances': ['S-ORG', 'O', 'S-MISC', 'B-PER', 'E-PER', 'S-LOC', 'B-ORG', 'E-ORG', 'I-PER', 'S-PER', 'B-MISC', 'I-MISC', 'E-MISC', 'I-ORG', 'B-LOC', 'E-LOC', 'I-LOC']}
#      FEATURE num: 0
#  ++++++++++++++++++++++++++++++++++++++++
#  Model Network:
#      Model        use_crf: False
#      Model low level transformer: None; Finetune: False
#      Model high level transformer: bert-base-cased; Finetune: True
#      Classification_Head: False; Classification_Head Activation: tahn
#      Classifier         dropout: 0.1
#  ++++++++++++++++++++++++++++++++++++++++
#  Training:
#      Optimizer: AdamW
#      Scheduler: get_cosine_schedule_with_warmup
#      warmup_step_rate: 0.050000
#      Iteration: 10
#      BatchSize: 16
#      Average  batch   loss: False
#  ++++++++++++++++++++++++++++++++++++++++
#  Hyperparameters:
#      Hyper              lr: 3e-05
#      Hyper         HP_clip: None
#      Hyper        momentum: 0
#      Hyper              l2: 1e-08
#      Hyper      hidden_dim: 768
#      Hyper         dropout: 0.3
#      Hyper             GPU: True
#      Hyper          device: cuda:0
# DATA SUMMARY END.
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Training model...
# build sequence labeling network...
# use_char:  False
# use crf:  False
# build word representation...
# Loading transformer... model: bert-base-cased
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
#  ++++++++++++++++++++++++++++++++++++++++
# BertConfig {
#   "_name_or_path": "bert-base-cased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
#  ++++++++++++++++++++++++++++++++++++++++
# Epoch: 0/10
# 100%|██████████| 8/8 [00:00<00:00, 28.67it/s]
# Dev: time: 0.28s, speed: 398.17st/s; acc: 0.8011, p: -1.0000, r: 0.0000, f: -1.0000
# INFO:test:Dev: time: 0.28s, speed: 398.17st/s; acc: 0.8011, p: -1.0000, r: 0.0000, f: -1.0000
# Right token =  1168  All token =  1458  acc =  0.8010973936899863
# 100%|██████████| 12/12 [00:00<00:00, 21.20it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.8712_p-1.0000_r0.0000_f-1.0000.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.8712_p-1.0000_r0.0000_f-1.0000.pth
# Test: time: 0.57s, speed: 327.61st/s; acc: 0.8712, p: -1.0000, r: 0.0000, f: -1.0000
# INFO:test:Test: time: 0.57s, speed: 327.61st/s; acc: 0.8712, p: -1.0000, r: 0.0000, f: -1.0000
# Right token =  3145  All token =  3610  acc =  0.871191135734072
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 1/10
# 100%|██████████| 8/8 [00:00<00:00, 30.81it/s]
# Dev: time: 0.26s, speed: 428.51st/s; acc: 0.8909, p: 0.4279, r: 0.4095, f: 0.4185
# INFO:test:Dev: time: 0.26s, speed: 428.51st/s; acc: 0.8909, p: 0.4279, r: 0.4095, f: 0.4185
# Right token =  1299  All token =  1458  acc =  0.8909465020576132
# 100%|██████████| 12/12 [00:00<00:00, 20.23it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9269_p0.5341_r0.5202_f0.5271.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9269_p0.5341_r0.5202_f0.5271.pth
# Right token =  3346  All token =  3610  acc =  0.9268698060941828
# Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9269_p0.5341_r0.5202_f0.5271.pth
# INFO:test:Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9269_p0.5341_r0.5202_f0.5271.pth
# Test: time: 0.60s, speed: 312.29st/s; acc: 0.9269, p: 0.5341, r: 0.5202, f: 0.5271
# INFO:test:Test: time: 0.60s, speed: 312.29st/s; acc: 0.9269, p: 0.5341, r: 0.5202, f: 0.5271
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 2/10
# 100%|██████████| 8/8 [00:00<00:00, 30.64it/s]
# Dev: time: 0.27s, speed: 425.75st/s; acc: 0.9300, p: 0.6847, r: 0.6619, f: 0.6731
# INFO:test:Dev: time: 0.27s, speed: 425.75st/s; acc: 0.9300, p: 0.6847, r: 0.6619, f: 0.6731
# Right token =  1356  All token =  1458  acc =  0.9300411522633745
# 100%|██████████| 12/12 [00:00<00:00, 20.40it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9402_p0.5819_r0.5954_f0.5886.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9402_p0.5819_r0.5954_f0.5886.pth
# Right token =  3394  All token =  3610  acc =  0.9401662049861496
# Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9402_p0.5819_r0.5954_f0.5886.pth
# INFO:test:Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9402_p0.5819_r0.5954_f0.5886.pth
# Test: time: 0.60s, speed: 314.95st/s; acc: 0.9402, p: 0.5819, r: 0.5954, f: 0.5886
# INFO:test:Test: time: 0.60s, speed: 314.95st/s; acc: 0.9402, p: 0.5819, r: 0.5954, f: 0.5886
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 3/10
# 100%|██████████| 8/8 [00:00<00:00, 31.41it/s]
# Dev: time: 0.26s, speed: 435.90st/s; acc: 0.9424, p: 0.7438, r: 0.7190, f: 0.7312
# INFO:test:Dev: time: 0.26s, speed: 435.90st/s; acc: 0.9424, p: 0.7438, r: 0.7190, f: 0.7312
# Right token =  1374  All token =  1458  acc =  0.9423868312757202
# 100%|██████████| 12/12 [00:00<00:00, 22.07it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9524_p0.6599_r0.6561_f0.6580.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9524_p0.6599_r0.6561_f0.6580.pth
# Right token =  3438  All token =  3610  acc =  0.9523545706371191
# Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9524_p0.6599_r0.6561_f0.6580.pth
# INFO:test:Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9524_p0.6599_r0.6561_f0.6580.pth
# Test: time: 0.55s, speed: 340.16st/s; acc: 0.9524, p: 0.6599, r: 0.6561, f: 0.6580
# INFO:test:Test: time: 0.55s, speed: 340.16st/s; acc: 0.9524, p: 0.6599, r: 0.6561, f: 0.6580
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 4/10
# 100%|██████████| 8/8 [00:00<00:00, 27.64it/s]
# Dev: time: 0.29s, speed: 383.56st/s; acc: 0.9568, p: 0.8086, r: 0.8048, f: 0.8067
# INFO:test:Dev: time: 0.29s, speed: 383.56st/s; acc: 0.9568, p: 0.8086, r: 0.8048, f: 0.8067
# Right token =  1395  All token =  1458  acc =  0.9567901234567902
# 100%|██████████| 12/12 [00:00<00:00, 20.54it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9632_p0.7320_r0.7341_f0.7330.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9632_p0.7320_r0.7341_f0.7330.pth
# Right token =  3477  All token =  3610  acc =  0.9631578947368421
# Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9632_p0.7320_r0.7341_f0.7330.pth
# INFO:test:Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9632_p0.7320_r0.7341_f0.7330.pth
# Test: time: 0.60s, speed: 315.90st/s; acc: 0.9632, p: 0.7320, r: 0.7341, f: 0.7330
# INFO:test:Test: time: 0.60s, speed: 315.90st/s; acc: 0.9632, p: 0.7320, r: 0.7341, f: 0.7330
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 5/10
# 100%|██████████| 8/8 [00:00<00:00, 27.24it/s]
# Dev: time: 0.30s, speed: 378.61st/s; acc: 0.9561, p: 0.7952, r: 0.7952, f: 0.7952
# INFO:test:Dev: time: 0.30s, speed: 378.61st/s; acc: 0.9561, p: 0.7952, r: 0.7952, f: 0.7952
# Right token =  1394  All token =  1458  acc =  0.9561042524005487
# 100%|██████████| 12/12 [00:00<00:00, 19.62it/s]
# Test: time: 0.62s, speed: 302.82st/s; acc: 0.9640, p: 0.7450, r: 0.7514, f: 0.7482
# INFO:test:Test: time: 0.62s, speed: 302.82st/s; acc: 0.9640, p: 0.7450, r: 0.7514, f: 0.7482
# Right token =  3480  All token =  3610  acc =  0.96398891966759
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 6/10
# 100%|██████████| 8/8 [00:00<00:00, 31.76it/s]
# Dev: time: 0.26s, speed: 440.59st/s; acc: 0.9636, p: 0.8436, r: 0.8476, f: 0.8456
# INFO:test:Dev: time: 0.26s, speed: 440.59st/s; acc: 0.9636, p: 0.8436, r: 0.8476, f: 0.8456
# Right token =  1405  All token =  1458  acc =  0.9636488340192044
# 100%|██████████| 12/12 [00:00<00:00, 22.19it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9654_p0.7572_r0.7572_f0.7572.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9654_p0.7572_r0.7572_f0.7572.pth
# Right token =  3485  All token =  3610  acc =  0.9653739612188366
# Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9654_p0.7572_r0.7572_f0.7572.pth
# INFO:test:Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9654_p0.7572_r0.7572_f0.7572.pth
# Test: time: 0.55s, speed: 342.63st/s; acc: 0.9654, p: 0.7572, r: 0.7572, f: 0.7572
# INFO:test:Test: time: 0.55s, speed: 342.63st/s; acc: 0.9654, p: 0.7572, r: 0.7572, f: 0.7572
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 7/10
# 100%|██████████| 8/8 [00:00<00:00, 28.00it/s]
# Dev: time: 0.29s, speed: 388.72st/s; acc: 0.9712, p: 0.8798, r: 0.8714, f: 0.8756
# INFO:test:Dev: time: 0.29s, speed: 388.72st/s; acc: 0.9712, p: 0.8798, r: 0.8714, f: 0.8756
# Right token =  1416  All token =  1458  acc =  0.9711934156378601
# 100%|██████████| 12/12 [00:00<00:00, 19.20it/s]
# Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9687_p0.7803_r0.7803_f0.7803.pth
# INFO:test:Save current best acc model in file:/home/zqwang/YATO-Github/sample_data/acc0.9687_p0.7803_r0.7803_f0.7803.pth
# Right token =  3497  All token =  3610  acc =  0.9686980609418283
# Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9687_p0.7803_r0.7803_f0.7803.pth
# INFO:test:Save current best f model in file:/home/zqwang/YATO-Github/sample_data/acc0.9687_p0.7803_r0.7803_f0.7803.pth
# Test: time: 0.63s, speed: 295.82st/s; acc: 0.9687, p: 0.7803, r: 0.7803, f: 0.7803
# INFO:test:Test: time: 0.63s, speed: 295.82st/s; acc: 0.9687, p: 0.7803, r: 0.7803, f: 0.7803
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 8/10
# 100%|██████████| 8/8 [00:00<00:00, 24.73it/s]
# Dev: time: 0.33s, speed: 343.94st/s; acc: 0.9698, p: 0.8673, r: 0.8714, f: 0.8694
# INFO:test:Dev: time: 0.33s, speed: 343.94st/s; acc: 0.9698, p: 0.8673, r: 0.8714, f: 0.8694
# Right token =  1414  All token =  1458  acc =  0.9698216735253772
# 100%|██████████| 12/12 [00:00<00:00, 20.58it/s]
# Test: time: 0.59s, speed: 317.04st/s; acc: 0.9665, p: 0.7528, r: 0.7659, f: 0.7593
# INFO:test:Test: time: 0.59s, speed: 317.04st/s; acc: 0.9665, p: 0.7528, r: 0.7659, f: 0.7593
# Right token =  3489  All token =  3610  acc =  0.9664819944598338
# Current Learning Rate: 3e-05
# INFO:test:Current Learning Rate: 3e-05
# Epoch: 9/10
# 100%|██████████| 8/8 [00:00<00:00, 31.79it/s]
# Dev: time: 0.26s, speed: 441.40st/s; acc: 0.9691, p: 0.8599, r: 0.8476, f: 0.8537
# INFO:test:Dev: time: 0.26s, speed: 441.40st/s; acc: 0.9691, p: 0.8599, r: 0.8476, f: 0.8537
# Right token =  1413  All token =  1458  acc =  0.9691358024691358
# 100%|██████████| 12/12 [00:00<00:00, 19.61it/s]
# Test: time: 0.62s, speed: 302.47st/s; acc: 0.9665, p: 0.7644, r: 0.7688, f: 0.7666
# INFO:test:Test: time: 0.62s, speed: 302.47st/s; acc: 0.9665, p: 0.7644, r: 0.7688, f: 0.7666
# Right token =  3489  All token =  3610  acc =  0.9664819944598338
# Best Test F1 Score: 0.7803468208092486, Best Validation F1 Score: 0.8755980861244019, Best Test F1 Score Epoch: 7
# INFO:test:Best Test F1 Score: 0.7803468208092486, Best Validation F1 Score: 0.8755980861244019, Best Test F1 Score Epoch: 7

# %% [markdown]
# ## Decode
# Decode Configuration
#
# status=decode
# raw_dir=The path of decode file
# nbest=0 (NER)/1 (sentence classification)
# decode_dir=The path of decode result file
# load_model_dir=The path of model weights
# sentence_classification=True/False

# %%
from yato import YATO
decode_model = YATO('decode.config')#configuration file
result_dict = decode_model.decode()
# Out:
# MODEL: decode
# nbest: 0
# Load Model from file: /home/zqwang/YATO-Github/sample_data/
# build sequence labeling network...
# use_char:  False
# use crf:  False
# build word representation...
# Loading transformer... model: bert-base-cased
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
#  ++++++++++++++++++++++++++++++++++++++++
# BertConfig {
#   "_name_or_path": "bert-base-cased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 28996
# }
#
#  ++++++++++++++++++++++++++++++++++++++++
# Decode predict data, nbest: 0 ...
# 100%|██████████| 12/12 [00:00<00:00, 18.79it/s]
# Right token =  3470  All token =  3610  acc =  0.961218836565097
# predict: time:0.64s, speed:290.20st/s; acc: 0.9612, p: 0.7217, r: 0.7197, f: 0.7207
# len(content_list) 186 186
# Predict predict result has been written into file. test.decode

# %% [markdown]
# ## Example

# %%
### use # to comment out the configure item

### I/O ###
train_dir=demo.train.bioes
dev_dir=demo.dev.bioes
test_dir=demo.test.bioes
model_dir=test/

dset_dir=bert_base_cased.dset

norm_word_emb=False
norm_char_emb=False
number_normalized=False
seg=True
word_emb_dim=50
char_emb_dim=30

###NetworkConfiguration###
use_crf=False
use_char=False
char_seq_feature=CNN
use_word_seq=False
use_word_emb=True
word_seq_feature=LSTM
low_level_transformer=None
low_level_transformer_finetune=False
high_level_transformer=bert-base-cased
high_level_transformer_finetune=True

###TrainingSetting###
status=train
optimizer=AdamW
iteration=10
batch_size=16
ave_batch_loss=False

###Hyperparameters###
cnn_layer=4
char_hidden_dim=50
hidden_dim=768
dropout=0.3
lstm_layer=2
bilstm=True
learning_rate=3e-5
gpu=True
device=cuda:0
scheduler=get_cosine_schedule_with_warmup
warmup_step_rate=0.05

# %%
status=decode
raw_dir=demo.test.bioes
nbest=0
decode_dir=test.decode
load_model_dir=test/acc: 0.9777, p: 0.8973, r: 0.8973, f: 0.8973.pth      
sentence_classification=False
